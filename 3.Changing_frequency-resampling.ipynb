# %% [markdown]
# ### Changing the time series frequency: resampling
#
# You will begin to learn how to change the frequency of a time series. This is a very common operation because you often need to convert two time series to a common frequency to analyze them together

# %% [markdown]
# #### Convert monthly to weekly data
#
# We'll lear how to use .reindex() to conform an existing time series to a DateTimeIndex at a different frequency.
#
# Let's practice this method by creating monthly data and then converting this data to weekly frequency while applying various fill logic options.

# %%
#libraries
import pandas as pd 
from datetime import datetime #To manually create dates
import matplotlib.pyplot as plt

# %%
# Set start and end dates
start = '2016-1-1'
end = '2016-2-29'

# %%
#Create monthly_dates using pd.date_range with start, end and frequency alias 'M'
monthly_dates = pd.date_range(start=start, end=end, freq="M")

# %%
#Create and print the pd.Series monthly, passing the list [1, 2] as the data argument, and using monthly_dates as index
monthly = pd.Series(data=[1,2], index=monthly_dates)
print(monthly)
# Out:
# 2016-01-31    1
# 2016-02-29    2
# Freq: M, dtype: int64

# %%
#Create weekly_dates using pd.date_range with start, end and frequency alias 'W
weekly_dates = pd.date_range(start=start, end=end, freq="W")
weekly_dates
# Out:
# DatetimeIndex(['2016-01-03', '2016-01-10', '2016-01-17', '2016-01-24',
#                '2016-01-31', '2016-02-07', '2016-02-14', '2016-02-21',
#                '2016-02-28'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
#Apply .reindex() to monthly without additional options and print it
print(monthly.reindex(weekly_dates))
# Out:
# 2016-01-03    NaN
# 2016-01-10    NaN
# 2016-01-17    NaN
# 2016-01-24    NaN
# 2016-01-31    1.0
# 2016-02-07    NaN
# 2016-02-14    NaN
# 2016-02-21    NaN
# 2016-02-28    NaN
# Freq: W-SUN, dtype: float64

# %%
#Apply .reindex() to monthly with bfill and print it
print(monthly.reindex(weekly_dates, method='bfill'))
# Out:
# 2016-01-03    1
# 2016-01-10    1
# 2016-01-17    1
# 2016-01-24    1
# 2016-01-31    1
# 2016-02-07    2
# 2016-02-14    2
# 2016-02-21    2
# 2016-02-28    2
# Freq: W-SUN, dtype: int64

# %%
#Apply .reindex() to monthly with ffill and print it
print(monthly.reindex(weekly_dates, method='ffill'))
# Out:
# 2016-01-03    NaN
# 2016-01-10    NaN
# 2016-01-17    NaN
# 2016-01-24    NaN
# 2016-01-31    1.0
# 2016-02-07    1.0
# 2016-02-14    1.0
# 2016-02-21    1.0
# 2016-02-28    1.0
# Freq: W-SUN, dtype: float64

# %% [markdown]
# #### Create weekly from monthly unemployment data
#
# The civilian US unemployment rate is reported monthly. You may need more frequent data, but that's no problem because you just learned how to upsample a time series.
#
# You'll work with the time series data for the last 20 years, and apply a few options to fill in missing values before plotting the weekly series.

# %%
#Use pd.read_csv() to import 'unemployment.csv', creating a DateTimeIndex from the 'date' column using parse_dates and index_col, and assign the result to data
data = pd.read_csv('datasets/Stock_data-/unemployment.csv', parse_dates=['date'], index_col='date')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 209 entries, 2000-01-01 to 2017-05-01
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  209 non-null    int64
#  1   UNRATE      209 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.9 KB

# %%
data.head(10)
# Out:
#             Unnamed: 0  UNRATE
# date
# 2000-01-01           0     4.0
# 2000-02-01           1     4.1
# 2000-03-01           2     4.0
# 2000-04-01           3     3.8
# 2000-05-01           4     4.0
# 2000-06-01           5     4.0
# 2000-07-01           6     4.0
# 2000-08-01           7     4.1
# 2000-09-01           8     3.9
# 2000-10-01           9     3.9

# %%
#Convert data to weekly frequency using .asfreq() with the alias 'W' and show the first ten rows.
data.asfreq("W").head(10)
# Out:
#             Unnamed: 0  UNRATE
# date
# 2000-01-02         NaN     NaN
# 2000-01-09         NaN     NaN
# 2000-01-16         NaN     NaN
# 2000-01-23         NaN     NaN
# 2000-01-30         NaN     NaN
# 2000-02-06         NaN     NaN
# 2000-02-13         NaN     NaN
# 2000-02-20         NaN     NaN
# 2000-02-27         NaN     NaN
# 2000-03-05         NaN     NaN

# %%
#Convert again to weekly frequency, adding the option 'bfill' and show the first ten rows.
data.asfreq("W", method='bfill').head(10)
# Out:
#             Unnamed: 0  UNRATE
# date
# 2000-01-02           1     4.1
# 2000-01-09           1     4.1
# 2000-01-16           1     4.1
# 2000-01-23           1     4.1
# 2000-01-30           1     4.1
# 2000-02-06           2     4.0
# 2000-02-13           2     4.0
# 2000-02-20           2     4.0
# 2000-02-27           2     4.0
# 2000-03-05           3     3.8

# %%
#Create weekly series, now adding the option 'ffill', assign to weekly_ffill and show the first ten rows.
weekly_ffill = data.asfreq('W', method='ffill')
print(weekly_ffill.head(10))
# Out:
#             Unnamed: 0  UNRATE
# date
# 2000-01-02           0     4.0
# 2000-01-09           0     4.0
# 2000-01-16           0     4.0
# 2000-01-23           0     4.0
# 2000-01-30           0     4.0
# 2000-02-06           1     4.1
# 2000-02-13           1     4.1
# 2000-02-20           1     4.1
# 2000-02-27           1     4.1
# 2000-03-05           2     4.0

# %%
# Plot weekly_fill starting 2015 here 
weekly_ffill['2015':].plot()
plt.show()

# %% [markdown]
# The plots should help you compare the different fill methods in pandas

# %% [markdown]
# #### Use interpolation to create weekly employment data
#
# You have recently used the civilian US unemployment rate, and converted it from monthly to weekly frequency using simple forward or backfill methods.
#
# Compare your previous approach to the new .interpolate()

# %%
#Inspect monthly using .info()
monthly = pd.read_csv('datasets/Stock_data-/monthly.csv',parse_dates=['DATE'], index_col='DATE')
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85 entries, 2010-01-01 to 2017-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNRATE  85 non-null     float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
monthly.head()
# Out:
#             UNRATE
# DATE
# 2010-01-01     9.8
# 2010-02-01     9.8
# 2010-03-01     9.9
# 2010-04-01     9.9
# 2010-05-01     9.6

# %%
#Create a pd.date_range() with weekly dates, using the .min() and .max() of the index of monthly as start and end, 
#respectively, and assign the result to weekly_dates
weekly_dates = pd.date_range(monthly.index.min(), monthly.index.max(), freq='W')
weekly_dates
# Out:
# DatetimeIndex(['2010-01-03', '2010-01-10', '2010-01-17', '2010-01-24',
#                '2010-01-31', '2010-02-07', '2010-02-14', '2010-02-21',
#                '2010-02-28', '2010-03-07',
#                ...
#                '2016-10-30', '2016-11-06', '2016-11-13', '2016-11-20',
#                '2016-11-27', '2016-12-04', '2016-12-11', '2016-12-18',
#                '2016-12-25', '2017-01-01'],
#               dtype='datetime64[ns]', length=366, freq='W-SUN')

# %%
#Apply .reindex() using weekly_dates to monthly and assign the output to weekly
weekly =  monthly.reindex(weekly_dates)
weekly.head(10)
# Out:
#             UNRATE
# 2010-01-03     NaN
# 2010-01-10     NaN
# 2010-01-17     NaN
# 2010-01-24     NaN
# 2010-01-31     NaN
# 2010-02-07     NaN
# 2010-02-14     NaN
# 2010-02-21     NaN
# 2010-02-28     NaN
# 2010-03-07     NaN

# %%
#Create new columns 'ffill' and 'interpolated' by applying .ffill() and .interpolate() to weekly.UNRATE
weekly['ffill'] = weekly.UNRATE.ffill()
weekly['interpolated'] = weekly.UNRATE.interpolate()
weekly.tail(20)
# Out:
#             UNRATE  ffill  interpolated
# 2016-08-21     NaN    4.7      4.745714
# 2016-08-28     NaN    4.7      4.748571
# 2016-09-04     NaN    4.7      4.751429
# 2016-09-11     NaN    4.7      4.754286
# 2016-09-18     NaN    4.7      4.757143
# 2016-09-25     NaN    4.7      4.760000
# 2016-10-02     NaN    4.7      4.762857
# 2016-10-09     NaN    4.7      4.765714
# 2016-10-16     NaN    4.7      4.768571
# 2016-10-23     NaN    4.7      4.771429
# 2016-10-30     NaN    4.7      4.774286
# 2016-11-06     NaN    4.7      4.777143
# 2016-11-13     NaN    4.7      4.780000
# 2016-11-20     NaN    4.7      4.782857
# 2016-11-27     NaN    4.7      4.785714
# 2016-12-04     NaN    4.7      4.788571
# 2016-12-11     NaN    4.7      4.791429
# 2016-12-18     NaN    4.7      4.794286
# 2016-12-25     NaN    4.7      4.797143
# 2017-01-01     4.8    4.8      4.800000

# %%
# Plot weekly
weekly.plot()
plt.show()

# %% [markdown]
# Fantastic work! Interpolating is a useful way to create smoother time series when resampling

# %% [markdown]
# #### Interpolate debt/GDP and compare to unemployment
# Since you have learned how to interpolate time series, you can now apply this new skill to the quarterly debt/GDP series, and compare the result to the monthly unemployment rate.

# %%
#Use pd.read_csv() to import 'debt_unemployment.csv', creating a DateTimeIndex from the 'date' column using parse_dates and 
#index_col, and assign the result to data. print() the .info() of the data
data = pd.read_csv("datasets/Stock_data-/debt_unemployment.csv",parse_dates=['date'], index_col='date')
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89 entries, 2010-01-01 to 2017-05-01
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Debt/GDP      29 non-null     float64
#  1   Unemployment  89 non-null     float64
# dtypes: float64(2)
# memory usage: 2.1 KB
# None

# %%
data.tail()
# Out:
#              Debt/GDP  Unemployment
# date
# 2017-01-01  104.30607           4.8
# 2017-02-01        NaN           4.7
# 2017-03-01        NaN           4.5
# 2017-04-01        NaN           4.4
# 2017-05-01        NaN           4.3

# %%
#Apply .interpolate() to data and assign this to interpolated, then inspect the result
interpolated = data.interpolate()
interpolated.tail()
# Out:
#              Debt/GDP  Unemployment
# date
# 2017-01-01  104.30607           4.8
# 2017-02-01  104.30607           4.7
# 2017-03-01  104.30607           4.5
# 2017-04-01  104.30607           4.4
# 2017-05-01  104.30607           4.3

# %%
#Plot interpolated with 'Unemployment' on the secondary_y axis
interpolated.plot(secondary_y="Unemployment")
plt.show()

# %% [markdown]
# #### Compare weekly, monthly and annual ozone trends for NYC & LA
# you'll apply a new skill to ozone data for both NYC and LA since 2000 to compare the air quality trend at weekly, monthly and annual frequencies and explore how different resampling periods impact the visualization.

# %%
#Use pd.read_csv() to import 'ozone.csv' and set a DateTimeIndex based on the 'date' column using parse_dates and index_col, 
#assign the result to ozone and inspect using .info()
ozone = pd.read_csv("datasets/air_quality_Data-/ozone.csv",parse_dates=['date'], index_col='date')
ozone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6291 entries, 2000-01-01 to 2017-03-31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   6291 non-null   int64
#  1   Los Angeles  5488 non-null   float64
#  2   New York     6167 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 196.6 KB

# %%
ozone.head(10)
# Out:
#             Unnamed: 0  Los Angeles  New York
# date
# 2000-01-01           0     0.008375  0.004032
# 2000-01-02           1          NaN  0.009486
# 2000-01-03           2          NaN  0.005580
# 2000-01-04           3     0.005500  0.008717
# 2000-01-05           4     0.005000  0.013754
# 2000-01-06           5     0.004917  0.009069
# 2000-01-07           6     0.004292  0.008333
# 2000-01-08           7     0.005458  0.007639
# 2000-01-09           8     0.005958  0.004569
# 2000-01-10           9     0.005167  0.005833

# %%
# Calculate and plot the weekly average ozone trend
ozonew=ozone.resample('W').mean()
ozonew.head(10)
# Out:
#             Unnamed: 0  Los Angeles  New York
# date
# 2000-01-02         0.5     0.008375  0.006759
# 2000-01-09         5.0     0.005188  0.008237
# 2000-01-16        12.0     0.003714  0.012210
# 2000-01-23        19.0     0.003262  0.012002
# 2000-01-30        26.0     0.006405  0.011995
# 2000-02-06        33.0     0.007556  0.011289
# 2000-02-13        40.0     0.010667  0.008662
# 2000-02-20        47.0     0.010292  0.012454
# 2000-02-27        54.0     0.009467  0.011313
# 2000-03-05        61.0     0.012911  0.018188

# %%
ozonew.plot(y=["Los Angeles","New York"])
plt.show()

# %%
# Calculate and plot the monthly average ozone trend
ozonem=ozone.resample('M').mean()
ozonem.head(10)
# Out:
#             Unnamed: 0  Los Angeles  New York
# date
# 2000-01-31        15.0     0.004734  0.010443
# 2000-02-29        45.0     0.009648  0.011817
# 2000-03-31        75.0     0.016694  0.016810
# 2000-04-30       105.5     0.019926  0.019413
# 2000-05-31       136.0     0.025743  0.026535
# 2000-06-30       166.5     0.025487  0.029540
# 2000-07-31       197.0     0.022832  0.026753
# 2000-08-31       228.0     0.022505  0.022853
# 2000-09-30       258.5     0.017068  0.017776
# 2000-10-31       289.0     0.016342  0.013842

# %%
ozonem.plot(y=["Los Angeles","New York"])
plt.show()

# %%
# Calculate and plot the monthly average ozone trend
ozoneA=ozone.resample('A').mean()
ozoneA.head(10)
# Out:
#             Unnamed: 0  Los Angeles  New York
# date
# 2000-12-31       182.5     0.015956  0.017821
# 2001-12-31       548.0     0.017836  0.019622
# 2002-12-31       913.0     0.021553  0.018557
# 2003-12-31      1278.0     0.019196  0.017583
# 2004-12-31      1643.5     0.026934  0.017236
# 2005-12-31      2009.0     0.023280  0.018489
# 2006-12-31      2374.0     0.022506  0.019430
# 2007-12-31      2739.0     0.024478  0.019464
# 2008-12-31      3104.5     0.024637  0.020399
# 2009-12-31      3470.0     0.023309  0.020035

# %%
ozoneA.plot(y=["Los Angeles","New York"])
plt.show()

# %% [markdown]
# #### Compare monthly average stock prices for Facebook and Google
# Now, you'll apply your new resampling skills to daily stock price series for Facebook and Google for the 2015-2016 period to compare the trend of the monthly averages.

# %%
#Use pd.read_csv() to import 'stocks.csv' and set a DateTimeIndex based on the 'date' column using parse_dates and index_col,
#assign the result to stocks and inspect using .info()
stocks = pd.read_csv("Datasets/air_quality_Data-/stocks.csv",parse_dates=['date'], index_col='date')
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 504 entries, 2015-01-02 to 2016-12-30
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  504 non-null    int64
#  1   FB          504 non-null    float64
#  2   GOOG        504 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 15.8 KB

# %%
#plot stocks
stocks.plot(subplots=True)
plt.show()

# %%
#Create monthly_average by applying .resample() with monthly frequency to data, using .mean() to aggregate. Plot the result using subplots
monthly_average = stocks.resample("M").mean()
monthly_average.plot(subplots=True)
plt.show()

# %% [markdown]
# #### Compare quarterly GDP growth rate and stock returns
# With your new skill to downsample and aggregate time series, you can compare higher-frequency stock price series to lower-frequency economic time series.
#
# As a first example, let's compare the quarterly GDP growth rate to the quarterly rate of return on the (resampled) Dow Jones Industrial index of 30 large US stocks.
#
# GDP growth is reported at the beginning of each quarter for the previous quarter. To calculate matching stock returns, you'll resample the stock index to quarter start frequency using the alias 'QS', and aggregating using the .first() observations.

# %%
# Import and inspect gdp_growth here
gdp_growth = pd.read_csv("Datasets/Stock_data-/gdp_growth.csv",parse_dates=['date'], index_col='date')
gdp_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 41 entries, 2007-01-01 to 2017-01-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gdp_growth  41 non-null     float64
# dtypes: float64(1)
# memory usage: 656.0 bytes

# %%
gdp_growth.head()
# Out:
#             gdp_growth
# date
# 2007-01-01         0.2
# 2007-04-01         3.1
# 2007-07-01         2.7
# 2007-10-01         1.4
# 2008-01-01        -2.7

# %%
# Import and inspect djia here
djia = pd.read_csv("Datasets/Stock_data-/djia.csv",parse_dates=['date'], index_col='date')
djia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2610 entries, 2007-06-29 to 2017-06-29
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   djia    2519 non-null   float64
# dtypes: float64(1)
# memory usage: 40.8 KB

# %%
djia.head()
# Out:
#                 djia
# date
# 2007-06-29  13408.62
# 2007-07-02  13535.43
# 2007-07-03  13577.30
# 2007-07-04       NaN
# 2007-07-05  13565.84

# %%
#Resample djia using frequency alias 'QS', aggregate using .first(), and assign to djia_quarterly
djia_quarterly = djia.resample("QS").first()
djia_quarterly.head()
# Out:
#                 djia
# date
# 2007-04-01  13408.62
# 2007-07-01  13535.43
# 2007-10-01  14087.55
# 2008-01-01  13043.96
# 2008-04-01  12654.36

# %%
#Apply .pct_change() to djia_quarterly and .mul() by 100 to obtain djia_quarterly_return
djia_quarterly_return = djia_quarterly.pct_change().mul(100)
djia_quarterly_return .head()
# Out:
#                 djia
# date
# 2007-04-01       NaN
# 2007-07-01  0.945735
# 2007-10-01  4.079072
# 2008-01-01 -7.407889
# 2008-04-01 -2.986823

# %%
#Use pd.concat() to concatenate gdp_growth and djia_quarterly_return along axis=1, and assign to data
data = pd.concat([gdp_growth, djia_quarterly_return], axis=1)
data.head()
# Out:
#             gdp_growth      djia
# date
# 2007-01-01         0.2       NaN
# 2007-04-01         3.1       NaN
# 2007-07-01         2.7  0.945735
# 2007-10-01         1.4  4.079072
# 2008-01-01        -2.7 -7.407889

# %%
#Rename the columns using .columns and the new labels 'gdp' and 'djia', then .plot() the results.
data.columns = ['gdp', 'djia']
data.plot()
plt.show()

# %% [markdown]
# #### Visualize monthly mean, median and standard deviation of S&P500 returns
# You have also learned how to calculate several aggregate statistics from upsampled data.
#
# Let's use this to explore how the monthly mean, median and standard deviation of daily S&P500 returns have trended over the last 10 years.

# %%
#Use pd.read_csv() to import 'sp500.csv', set a DateTimeIndex based on the 'date' column using parse_dates and index_col, assign the results to sp500
sp500=pd.read_csv("Datasets/Stock_data-/sp500.csv",parse_dates=['date'], index_col='date')
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2395 entries, 2007-06-29 to 2016-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SP500   2395 non-null   float64
# dtypes: float64(1)
# memory usage: 37.4 KB

# %%
sp500.head()
# Out:
#               SP500
# date
# 2007-06-29  1503.35
# 2007-07-02  1519.43
# 2007-07-03  1524.87
# 2007-07-05  1525.40
# 2007-07-06  1530.44

# %%
#Convert sp500 to a pd.Series() using .squeeze() and apply .pct_change() to calculate daily_returns
daily_returns = sp500.squeeze().pct_change()
daily_returns.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 2395 entries, 2007-06-29 to 2016-12-30
# Series name: SP500
# Non-Null Count  Dtype
# --------------  -----
# 2394 non-null   float64
# dtypes: float64(1)
# memory usage: 37.4 KB

# %%
daily_returns.head()
# Out:
# date
# 2007-06-29         NaN
# 2007-07-02    0.010696
# 2007-07-03    0.003580
# 2007-07-05    0.000348
# 2007-07-06    0.003304
# Name: SP500, dtype: float64

# %%
#.resample() daily_returns to month-end frequency (alias: 'M') and apply .agg() to calculate 'mean', 'median', and 'std'. Assign the result to stats.
stats = daily_returns.resample('M').agg(['mean', 'median', 'std'])
stats.head()
# Out:
#                 mean    median       std
# date
# 2007-06-30       NaN       NaN       NaN
# 2007-07-31 -0.001490  0.000921  0.010908
# 2007-08-31  0.000668  0.001086  0.015261
# 2007-09-30  0.001900  0.000202  0.010000
# 2007-10-31  0.000676 -0.000265  0.008719

# %%
# Plot stats here
stats.plot()
plt.show()
